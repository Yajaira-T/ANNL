# %% [markdown]
# Esto es una prueba:
# \begin{equation}
#     \int_a^b f'(x)fx = f(b) - f(a)
# \end{equation}

# %%
1+1
# Out:
# 2

# %%
import numpy as np
def punto_medio(f, a, b, N):
    h=(b-a)/N
